# %% [markdown]
# <a href="https://colab.research.google.com/github/ruthmanik/MagangPortofolio/blob/main/Ruth_Sani_Manik.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import library yang dibutuhkan
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Upload file jika belum ada di Google Colab
from google.colab import files
uploaded = files.upload()

# Membaca dataset
df = pd.read_csv("signal.csv")

# Menampilkan 5 baris pertama untuk melihat struktur data
print(df.head())

# Menampilkan informasi dataset
print(df.info())

# Menampilkan statistik deskriptif
print(df.describe())

# Pilih variabel target yang ingin dianalisis korelasinya
target_variable = "efisiensi"

# Filter kolom numerik sebelum menghitung korelasi
numerical_df = df.select_dtypes(include=['number'])  # Memilih hanya kolom numerik

# Menghitung korelasi antar variabel numerik
correlation_matrix = numerical_df.corr()
print("Matriks Korelasi:")
print(correlation_matrix)

# Pastikan Variabel target ada dalam dataframe numerik
if target_variable in numerical_df.columns:
    correlation = correlation_numerik[target_variable].sort_values(ascending=False)
    print(f"Korelasi dengan variabel '{target_variable}':")
    print(correlation)
else:
    print(f"Variabel target '{target_variable}' bukan numerik atau tidak ditemukan dalam dataset.")

# Visualisasi Heatmap Korelasi
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Heatmap Korelasi Variabel dalam Dataset")
plt.show()
# Out:
#      <input type="file" id="files-eaaf50bd-312b-4ebe-8b17-15896808a2fb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eaaf50bd-312b-4ebe-8b17-15896808a2fb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Import library yang dibutuhkan
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Upload file jika belum ada di Google Colab
from google.colab import files
uploaded = files.upload()

# Membaca dataset
df = pd.read_csv("signal.csv")

# Menampilkan 5 baris pertama untuk melihat struktur data
print(df.head())

# Menampilkan informasi dataset (tipe data dan missing values)
print(df.info())

# Menampilkan statistik deskriptif
print(df.describe())

# Pilih variabel target yang ingin dianalisis korelasinya (misalnya 'kepuasan')
target_variable = "Intensitas Penggunaan"  # Ganti dengan nama kolom yang sesuai

# --- Perubahan di sini ---
# Filter kolom numerik sebelum menghitung korelasi
numerical_df = df.select_dtypes(include=['number'])  # Memilih hanya kolom numerik

# Menghitung korelasi antar variabel numerik
correlation_matrix = numerical_df.corr()
print("Matriks Korelasi:")
print(correlation_matrix)

# Pastikan Variabel target ada dalam dataframe numerik
if target_variable in numerical_df.columns:
    correlation = correlation_numerik[target_variable].sort_values(ascending=False)
    print(f"Korelasi dengan variabel '{target_variable}':")
    print(correlation)
else:
    print(f"Variabel target '{target_variable}' bukan numerik atau tidak ditemukan dalam dataset.")

# Visualisasi Heatmap Korelasi
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Heatmap Korelasi Variabel dalam Dataset")
plt.show()
# Out:
#      <input type="file" id="files-726b725d-3af9-4170-8997-d589ee62ad9a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-726b725d-3af9-4170-8997-d589ee62ad9a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Import library
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# Upload file jika belum ada di Google Colab
from google.colab import files
uploaded = files.upload()

# Membaca dataset
df = pd.read_csv("signal.csv")

# Menampilkan 5 baris pertama untuk melihat struktur data
print(df.head())

# Menampilkan informasi dataset (tipe data dan missing values)
print(df.info())

# Pilih variabel numerik dan kategorikal
var_num = "Keamanan Data"  # Ganti dengan nama kolom numerik
var_cat = "Efisiensi"  # Ganti dengan nama kolom kategorikal

# Cek apakah variabel ada dalam dataset
if var_num in df.columns and var_cat in df.columns:
    # Cek apakah variabel kategorikal bersifat ordinal atau nominal
    print("Nilai unik dalam variabel kategorikal:", df[var_cat].unique())

    # Visualisasi dengan Boxplot
    plt.figure(figsize=(8,6))
    sns.boxplot(x=df[var_cat], y=df[var_num])
    plt.title(f"Distribusi {var_num} berdasarkan {var_cat}")
    plt.show()

else:
    print("Salah satu atau kedua variabel tidak ditemukan dalam dataset. Periksa kembali nama kolom!")
# Out:
#      <input type="file" id="files-bbfe4f15-bc08-4f31-886a-358318c8ade1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bbfe4f15-bc08-4f31-886a-358318c8ade1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Import library
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# Upload file jika belum ada di Google Colab
from google.colab import files
uploaded = files.upload()

# Membaca dataset (ganti 'nama_file.csv' dengan nama dataset yang diunggah)
df = pd.read_csv("signal.csv")

# Menampilkan 5 baris pertama untuk melihat struktur data
print(df.head())

# Menampilkan informasi dataset (tipe data dan missing values)
print(df.info())

# Pilih variabel numerik dan kategorikal
var_num = "Efisiensi"  # Ganti dengan nama kolom numerik
var_cat = "Intensitas Penggunaan"  # Ganti dengan nama kolom kategorikal

# Cek apakah variabel ada dalam dataset
if var_num in df.columns and var_cat in df.columns:
    # Cek apakah variabel kategorikal bersifat ordinal atau nominal
    print("Nilai unik dalam variabel kategorikal:", df[var_cat].unique())

    # Visualisasi dengan Boxplot
    plt.figure(figsize=(8,6))
    sns.boxplot(x=df[var_cat], y=df[var_num])
    plt.title(f"Distribusi {var_num} berdasarkan {var_cat}")
    plt.show()

else:
    print("Salah satu atau kedua variabel tidak ditemukan dalam dataset. Periksa kembali nama kolom!")
# Out:
#      <input type="file" id="files-18d85006-af32-40b2-995a-f3a513c2cc09" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-18d85006-af32-40b2-995a-f3a513c2cc09">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Import library
import pandas as pd

#Upload file (jika pakal Google Colab)
from google.colab import files
uploaded = files.upload()

#Membaca dataset
df = pd.read_csv("signal.csv")

#Pilih satu variabel untuk analisis univariat (gantilah dengan nama variabel yang sesuai)
variable = "Skor Intensitas"

#Menampilkan statistik deskriptif
if variable in df.columns:
   print(df[variable].describe())

else:
  print(f"Variabel '{variable}' tidak ditemukan dalam dataset.")

  #Boxplot untuk melihat distribusi data dan outlier

plt.figure(figsize=(6,4))
sns.boxplot(y=df[variable], color="orange")
plt.title(f"Boxplot Variabel {variable}")
plt.ylabel(variable)
plt.grid(True)
plt.show()
# Out:
#      <input type="file" id="files-86401f7e-9097-4284-a19b-9858fd001f7e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-86401f7e-9097-4284-a19b-9858fd001f7e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Import library
import pandas as pd

#Upload file (jika pakal Google Colab)
from google.colab import files
uploaded = files.upload()

#Membaca dataset
df = pd.read_csv("signal.csv")

#Pilih satu variabel untuk analisis univariat (gantilah dengan nama variabel yang sesuai)
variable = "Efisiensi"

#Menampilkan statistik deskriptif
if variable in df.columns:
   print(df[variable].describe())

else:
  print(f"Variabel '{variable}' tidak ditemukan dalam dataset.")

  #Boxplot untuk melihat distribusi data dan outlier

plt.figure(figsize=(6,4))
sns.boxplot(y=df[variable], color="Pink")
plt.title(f"Boxplot Variabel {variable}")
plt.ylabel(variable)
plt.grid(True)
plt.show()
# Out:
#      <input type="file" id="files-e8f40b24-88a6-46ba-9b4d-955461d18185" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e8f40b24-88a6-46ba-9b4d-955461d18185">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
